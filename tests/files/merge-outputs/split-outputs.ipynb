# %%
from sys import stderr
from time import sleep
stderr.write("before sleep\n")
sleep(1)
stderr.write("after sleep 1\n")
sleep(1)
stderr.write("after sleep 2\n");
# Out:
# before sleep
# after sleep 1
# after sleep 2
