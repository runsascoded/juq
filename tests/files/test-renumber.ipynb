# %% [markdown]
# # Test renumber `execution_count`s
#
# Markdown cells are unaffected

# %%
num = 111

# %% [markdown]
# Some more markdown

# %%
print(f"{num=}")
num * num
# Out:
# num=111
# 12321

# %% [markdown]
# Markdown!

# %%
from utz import err
err(f"stderr! {num=}")
# Out:
# stderr! num=111

# %%
from utz import err
err(f"stderr! {num=}")
num
# Out:
# stderr! num=111
# 111
